# %%
gdf["ndvi_mean"].describe()
# Out:
# count    9.000000
# mean     0.703961
# std      0.053082
# min      0.636477
# 25%      0.670956
# 50%      0.677692
# 75%      0.743834
# max      0.787787
# Name: ndvi_mean, dtype: float64

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

gdf = gpd.read_file("D:/geofarm_epic1_starter/data/processed/ndvi_zonal.geojson")

ax = gdf.plot(column="ndvi_mean", cmap="RdYlGn", legend=True, edgecolor="black", figsize=(7,6))
ax.set_title("Mean NDVI per Field")
plt.show()
# Out:
# c:\Users\pchuk\mambaforge\envs\geofarm311\Lib\site-packages\pyogrio\core.py:27: RuntimeWarning: Could not detect PROJ data files.  Set PROJ_LIB environment variable to the correct path.
#   _init_proj_data()
