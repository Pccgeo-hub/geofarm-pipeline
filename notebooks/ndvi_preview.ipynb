# %%
import rasterio
import matplotlib.pyplot as plt

with rasterio.open("D:/geofarm_epic1_starter/data/processed/ndvi.tif") as src:
    ndvi = src.read(1)

plt.imshow(ndvi, cmap="RdYlGn")
plt.colorbar(label="NDVI")
plt.title("NDVI Preview")
plt.show()
